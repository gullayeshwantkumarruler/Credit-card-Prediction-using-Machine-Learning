# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyspark --quiet
# Out:
#      |████████████████████████████████| 281.4 MB 46 kB/s
#      |████████████████████████████████| 199 kB 54.2 MB/s
#   Building wheel for pyspark (setup.py) ... done

# %% [markdown]
# ### <b>1. Obtaining the Data</b>
# This stage refers to collecting data.

# %%
import pyspark
import numpy as np
import random
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from pyspark import SparkConf
from pyspark.sql import Window
import pyspark.sql.functions as F
from pyspark.ml.feature import VectorAssembler, StandardScaler, OneHotEncoder, StringIndexer
from pyspark.ml.classification import LogisticRegression, GBTClassifier, RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)

# %%
train_path="/content/drive/MyDrive/Freelance/Credit score prediction/train.csv"
test_path="/content/drive/MyDrive/Freelance/Credit score prediction/test.csv"

# %%
# lOADING THE DATASET
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","
df = spark.read.load(train_path,format='csv',header='true', inferSchema='true')
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
data_test=spark.read.load(test_path,format='csv',header='true', inferSchema='true')

# %%
df.printSchema()
# Out:
# root
#  |-- ID: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- SSN: string (nullable = true)
#  |-- Occupation: string (nullable = true)
#  |-- Annual_Income: string (nullable = true)
#  |-- Monthly_Inhand_Salary: double (nullable = true)
#  |-- Num_Bank_Accounts: integer (nullable = true)
#  |-- Num_Credit_Card: integer (nullable = true)
#  |-- Interest_Rate: integer (nullable = true)
#  |-- Num_of_Loan: string (nullable = true)
#  |-- Type_of_Loan: string (nullable = true)
#  |-- Delay_from_due_date: integer (nullable = true)
#  |-- Num_of_Delayed_Payment: string (nullable = true)
#  |-- Changed_Credit_Limit: string (nullable = true)
#  |-- Num_Credit_Inquiries: double (nullable = true)
#  |-- Credit_Mix: string (nullable = true)
#  |-- Outstanding_Debt: string (nullable = true)
#  |-- Credit_Utilization_Ratio: double (nullable = true)
#  |-- Credit_History_Age: string (nullable = true)
#  |-- Payment_of_Min_Amount: string (nullable = true)
#  |-- Total_EMI_per_month: double (nullable = true)
#  |-- Amount_invested_monthly: string (nullable = true)
#  |-- Payment_Behaviour: string (nullable = true)
#  |-- Monthly_Balance: string (nullable = true)
#  |-- Credit_Score: string (nullable = true)

# %%
df.head()
# Out:
# Row(ID='0x1602', Customer_ID='CUS_0xd40', Month='January', Name='Aaron Maashoh', Age='23', SSN='821-00-0265', Occupation='Scientist', Annual_Income='19114.12', Monthly_Inhand_Salary=1824.8433333333328, Num_Bank_Accounts=3, Num_Credit_Card=4, Interest_Rate=3, Num_of_Loan='4', Type_of_Loan='Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan', Delay_from_due_date=3, Num_of_Delayed_Payment='7', Changed_Credit_Limit='11.27', Num_Credit_Inquiries=4.0, Credit_Mix='_', Outstanding_Debt='809.98', Credit_Utilization_Ratio=26.822619623699016, Credit_History_Age='22 Years and 1 Months', Payment_of_Min_Amount='No', Total_EMI_per_month=49.57494921489417, Amount_invested_monthly='80.41529543900253', Payment_Behaviour='High_spent_Small_value_payments', Monthly_Balance='312.49408867943663', Credit_Score='Good')

# %%
# inorder to get the functionality of data.shape as we used in pandas we can do in this way over here
print('Without any conversion: ',(df.count(), len(df.columns)))
# or if the dataset is small we can convert this into pandas dataframe and then use the functionallity of pandas
# we can observe that both of them will return same value
import pandas as pd    
spark.conf.set("spark.sql.execution.arrow.enabled", "true")
pandasDF=df.toPandas()
print('By converting from spark to Pandas: ',pandasDF.shape)
# Out:
# Without any conversion:  (100000, 28)
# By converting from spark to Pandas:  (100000, 28)

# %%
df.columns
# Out:
# ['ID',
#  'Customer_ID',
#  'Month',
#  'Name',
#  'Age',
#  'SSN',
#  'Occupation',
#  'Annual_Income',
#  'Monthly_Inhand_Salary',
#  'Num_Bank_Accounts',
#  'Num_Credit_Card',
#  'Interest_Rate',
#  'Num_of_Loan',
#  'Type_of_Loan',
#  'Delay_from_due_date',
#  'Num_of_Delayed_Payment',
#  'Changed_Credit_Limit',
#  'Num_Credit_Inquiries',
#  'Credit_Mix',
#  'Outstanding_Debt',
#  'Credit_Utilization_Ratio',
#  'Credit_History_Age',
#  'Payment_of_Min_Amount',
#  'Total_EMI_per_month',
#  'Amount_invested_monthly',
#  'Payment_Behaviour',
#  'Monthly_Balance',
#  'Credit_Score']

# %%
df.dtypes
# Out:
# [('ID', 'string'),
#  ('Customer_ID', 'string'),
#  ('Month', 'string'),
#  ('Name', 'string'),
#  ('Age', 'string'),
#  ('SSN', 'string'),
#  ('Occupation', 'string'),
#  ('Annual_Income', 'string'),
#  ('Monthly_Inhand_Salary', 'double'),
#  ('Num_Bank_Accounts', 'int'),
#  ('Num_Credit_Card', 'int'),
#  ('Interest_Rate', 'int'),
#  ('Num_of_Loan', 'string'),
#  ('Type_of_Loan', 'string'),
#  ('Delay_from_due_date', 'int'),
#  ('Num_of_Delayed_Payment', 'string'),
#  ('Changed_Credit_Limit', 'string'),
#  ('Num_Credit_Inquiries', 'double'),
#  ('Credit_Mix', 'string'),
#  ('Outstanding_Debt', 'string'),
#  ('Credit_Utilization_Ratio', 'double'),
#  ('Credit_History_Age', 'string'),
#  ('Payment_of_Min_Amount', 'string'),
#  ('Total_EMI_per_month', 'double'),
#  ('Amount_invested_monthly', 'string'),
#  ('Payment_Behaviour', 'string'),
#  ('Monthly_Balance', 'string'),
#  ('Credit_Score', 'string')]

# %%
df=df.withColumn("Age",df.Age.cast('int'))
df.Annual_Income = df.withColumn("Annual_Income",df.Annual_Income.cast('float'))
df.Num_of_Loan = df.withColumn("Num_of_Loan",df.Num_of_Loan.cast('int'))
df.Num_of_Delayed_Payment = df.withColumn("Num_of_Delayed_Payment",df.Num_of_Delayed_Payment.cast('float'))
df.Changed_Credit_Limit = df.withColumn("Changed_Credit_Limit",df.Changed_Credit_Limit.cast('float'))
df.Outstanding_Debt = df.withColumn("Outstanding_Debt",df.Outstanding_Debt.cast('float'))
df.Amount_invested_monthly = df.withColumn("Amount_invested_monthly",df.Amount_invested_monthly.cast('float'))
df.Monthly_Balance = df.withColumn("Monthly_Balance",df.Monthly_Balance.cast('float'))

# %%
df.dtypes
# Out:
# [('ID', 'string'),
#  ('Customer_ID', 'string'),
#  ('Month', 'string'),
#  ('Name', 'string'),
#  ('Age', 'int'),
#  ('SSN', 'string'),
#  ('Occupation', 'string'),
#  ('Annual_Income', 'string'),
#  ('Monthly_Inhand_Salary', 'double'),
#  ('Num_Bank_Accounts', 'int'),
#  ('Num_Credit_Card', 'int'),
#  ('Interest_Rate', 'int'),
#  ('Num_of_Loan', 'string'),
#  ('Type_of_Loan', 'string'),
#  ('Delay_from_due_date', 'int'),
#  ('Num_of_Delayed_Payment', 'string'),
#  ('Changed_Credit_Limit', 'string'),
#  ('Num_Credit_Inquiries', 'double'),
#  ('Credit_Mix', 'string'),
#  ('Outstanding_Debt', 'string'),
#  ('Credit_Utilization_Ratio', 'double'),
#  ('Credit_History_Age', 'string'),
#  ('Payment_of_Min_Amount', 'string'),
#  ('Total_EMI_per_month', 'double'),
#  ('Amount_invested_monthly', 'string'),
#  ('Payment_Behaviour', 'string'),
#  ('Monthly_Balance', 'string'),
#  ('Credit_Score', 'string')]

# %% [markdown]
# ###<b>2. Scrubbing the Data</b>
# Scrubbing the data typically involves missing value imputation, data type conversion, standardization, and renaming columns.

# %%
# removing unwanted characters
temp = df.toPandas().applymap(lambda x: x if x is np.NaN or not isinstance(x, str) else str(x).strip('_ ,"')).replace(['', 'nan', '!@9#%8', '#F%$D@*&8'], np.NaN)
df=spark.createDataFrame(temp)

# %% [markdown]
# ####<b>2.1. Imputing Missing Values

# %% [markdown]
# ##### <u>2.1.1. checking for the count of null values in all columns

# %%
for i in df.columns:
  print("missing in",i,df.filter(df[i].isNull()).count())
# Out:
# missing in ID 0
# missing in Customer_ID 0
# missing in Month 0
# missing in Name 9985
# missing in Age 4939
# missing in SSN 5572
# missing in Occupation 7062
# missing in Annual_Income 0
# missing in Monthly_Inhand_Salary 15002
# missing in Num_Bank_Accounts 0
# missing in Num_Credit_Card 0
# missing in Interest_Rate 0
# missing in Num_of_Loan 0
# missing in Type_of_Loan 11408
# missing in Delay_from_due_date 0
# missing in Num_of_Delayed_Payment 7002
# missing in Changed_Credit_Limit 2091
# missing in Num_Credit_Inquiries 1965
# missing in Credit_Mix 20195
# missing in Outstanding_Debt 0
# missing in Credit_Utilization_Ratio 0
# missing in Credit_History_Age 0
# missing in Payment_of_Min_Amount 0
# missing in Total_EMI_per_month 0
# missing in Amount_invested_monthly 4479
# missing in Payment_Behaviour 7600
# missing in Monthly_Balance 1200
# missing in Credit_Score 0

# %%
for i in df.columns:
  if df.filter(df[i].isNull()).count()>0:
    print(i)
# Out:
# Name
# Age
# SSN
# Occupation
# Monthly_Inhand_Salary
# Type_of_Loan
# Num_of_Delayed_Payment
# Changed_Credit_Limit
# Num_Credit_Inquiries
# Credit_Mix
# Amount_invested_monthly
# Payment_Behaviour
# Monthly_Balance

# %% [markdown]
# ##### <u>2.1.2. Checking the rows which contains the null values

# %%
# Here we will be checking the null values present in each column
for i in df.columns:
  print("missing in",i,df.filter(df[i].isNull()).show())
# Out:
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# | ID|Customer_ID|Month|Name|Age|SSN|Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|Payment_Behaviour|Monthly_Balance|Credit_Score|
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
#
# missing in ID None
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# | ID|Customer_ID|Month|Name|Age|SSN|Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|Payment_Behaviour|Monthly_Balance|Credit_Score|
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
#
# missing in Customer_ID None
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# | ID|Customer_ID|Month|Name|Age|SSN|Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|Payment_Behaviour|Monthly_Balance|Credit_Score|
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
#
# missing in Month None
# +------+-----------+--------+----+------+-----------+------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |    ID|Customer_ID|   Month|Name|   Age|        SSN|  Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|        Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|  Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|   Payment_Behaviour|   Monthly_Balance|Credit_Score|
# +------+-----------+--------+----+------+-----------+------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |0x1609|  CUS_0xd40|  August|null|  23.0|       null|   Scientist|     19114.12|   1824.8433333333328|                3|              4|            3|          4|Auto Loan, Credit...|                  3|                     6|               11.27|                 4.0|      Good|          809.98|       23.93379480196552|                  NA|                   No|  49.57494921489417|     24.785216509052056|High_spent_Medium...|358.12416760938714|    Standard|
# |0x161b| CUS_0x2dbc|February|null|  34.0|486-85-3974|    Engineer|    143162.64|             12187.22|                1|              5|            8|          3|Auto Loan, Auto L...|                 13|                     6|                 7.1|                 3.0|      Good|         1303.01|       41.70257342393906|17 Years and 10 M...|                   No|  246.9923194537421|     232.86038375993544|High_spent_Small_...| 998.8692967863226|        Good|
# |0x1620| CUS_0x2dbc|    July|null|  34.0|486-85-3974|    Engineer|    143162.64|             12187.22|                1|              5|            8|          3|Auto Loan, Auto L...|                  8|                     6|                 7.1|                 3.0|      Good|         1303.01|      38.068623627698585|18 Years and 3 Mo...|                   No|  246.9923194537421|     263.17416316163934|High_spent_Small_...| 968.5555173846187|    Standard|
# |0x1662| CUS_0x4157| January|null|  23.0|070-19-1622|      Doctor|    114838.41|            9843.8675|                2|              5|            7|       -100|Personal Loan, De...|                 13|                    11|                8.24|                 3.0|      Good|         1377.74|       33.66455429077268|21 Years and 4 Mo...|                   No| 226.89279192154316|     215.19351594560425|High_spent_Small_...| 802.3004421328528|        Good|
# |0x167a| CUS_0xa66b| January|null|  40.0|221-30-8554|     Teacher|     33751.27|    2948.605833333333|                5|              5|           20|          3|Credit-Builder Lo...|                 16|                    20|                11.0|                 4.0|  Standard|         1328.93|       37.08907564543987|19 Years and 2 Mo...|                   NM|  65.00817428651536|     117.30669710658556|High_spent_Medium...|362.54571194023237|    Standard|
# |0x16a3| CUS_0x6c66|    June|null|  39.0|328-33-6328|     Manager|     8701.545|            519.12875|                6|              5|           32|          7|Personal Loan, Pa...|                 23|                     6|                null|                 6.0|  Standard|         2602.69|      28.570031407996353|9 Years and 4 Months|                  Yes|  36.54819717138717|     52.931613407134115|Low_spent_Medium_...|242.43306442147872|        Poor|
# |0x16a4| CUS_0x6c66|    July|null|  39.0|328-33-6328|     Manager|     8701.545|                 null|                6|              5|           32|          7|Personal Loan, Pa...|                 21|                     9|                null|                 9.0|  Standard|         2602.69|       38.46541540543407|                  NA|                  Yes|  36.54819717138717|     30.471806299271933|Low_spent_Medium_...| 264.8928715293409|        Poor|
# |0x16ab|  CUS_0xff4|February|null|-500.0|655-05-7666|Entrepreneur|     25546.26|                 null|                8|              7|           14|          5|Not Specified, St...|                 16|                    13|                7.83|                null|  Standard|          758.44|      29.711375540929513|18 Years and 3 Mo...|                  Yes|  101.3286373638512|     300.32323168069064|Low_spent_Small_v...| 129.9336309554582|    Standard|
# |0x16c3| CUS_0x6070|February|null|  20.0|891-55-9364|  Accountant|     92047.08|              7591.59|                6|              7|           16|          0|                null|                 16|                    11|                9.13|                 4.0|  Standard|         1296.64|       39.46775837121139|29 Years and 3 Mo...|                  Yes|                0.0|      710.4953806729873|Low_spent_Medium_...|328.66361932701284|    Standard|
# |0x16c8| CUS_0x6070|    July|null|  20.0|891-55-9364|  Accountant|     92047.08|              7591.59|                6|              7|           16|          0|                null|                 16|                    10|                9.13|                 4.0|      null|         1296.64|       40.75852163733138|29 Years and 8 Mo...|                  Yes|                0.0|      59.28557022863863|High_spent_Large_...| 939.8734297713614|        Poor|
# |0x16f2| CUS_0x132f| January|null|  41.0|       null|    Musician|     19514.88|              1828.24|                7|              5|           17|          0|                null|                 30|                    12|                4.17|                 2.0|      null|           881.4|      26.084542750932684|19 Years and 3 Mo...|                   NM|                0.0|      50.14372713919671|High_spent_Medium...| 382.6802728608033|    Standard|
# |0x16f4| CUS_0x132f|   March|null|  41.0|561-60-9294|    Musician|     19514.88|              1828.24|                7|              5|           17|          0|                null|                 30|                    12|                4.17|                 2.0|  Standard|           881.4|       33.66946005394869|19 Years and 5 Mo...|                   No|                0.0|     43.315824459505386|High_spent_Medium...| 389.5081755404946|    Standard|
# |0x16f5| CUS_0x132f|   April|null|  41.0|561-60-9294|    Musician|     19514.88|              1828.24|                7|            488|           17|          0|                null|                 30|                    12|                4.17|                 2.0|  Standard|           881.4|      34.503707241298585|19 Years and 6 Mo...|                   No|                0.0|     45.388820313894996|High_spent_Medium...|387.43517968610496|        Poor|
# |0x170a| CUS_0xac86| January|null|  19.0|028-16-4402|Entrepreneur|    106733.13|            8873.4275|                4|              4|            1|          0|                null|                 10|                     8|                0.86|                 0.0|      null|           76.23|      29.815895626895166|32 Years and 9 Mo...|                   No|                0.0|     388.36035366098815|Low_spent_Large_v...| 768.9823963390119|        Good|
# |0x1711| CUS_0xac86|  August|null|  20.0|028-16-4402|Entrepreneur|    106733.13|            8873.4275|                4|              4|            1|          0|                null|                  7|                     6|                0.86|                 1.0|      Good|           76.23|       39.24363977621796|33 Years and 4 Mo...|                   No|                0.0|      384.7637247797149|                null| 792.5790252202852|    Standard|
# |0x1716| CUS_0x5b48| January|null|  null|706-95-0150|      Lawyer|    12600.445|    782.0370833333334|                5|              5|           10|       -100|Not Specified, St...|                 28|                    19|               15.79|                 7.0|      null|           569.8|       33.07588356651339|12 Years and 3 Mo...|                  Yes| 26.060347529205966|                    0.0|High_spent_Large_...| 284.2982044805207|    Standard|
# |0x1718| CUS_0x5b48|   March|null|  31.0|706-95-0150|      Lawyer|    12600.445|    782.0370833333334|                5|              5|           10|          3|Not Specified, St...|                 25|                    16|               15.79|                 7.0|  Standard|           569.8|       23.17983273627976|12 Years and 5 Mo...|                  Yes| 26.060347529205966|      32.02630794260436|Low_spent_Small_v...|  310.117052861523|    Standard|
# |0x1719| CUS_0x5b48|   April|null|  32.0|706-95-0150|        null|    12600.445|    782.0370833333334|                5|              5|           10|          3|Not Specified, St...|                 25|                    18|               15.79|                null|  Standard|           569.8|         28.819407058304|12 Years and 6 Mo...|                  Yes|            33746.0|      31.14919791081519|Low_spent_Medium_...| 300.9941628933122|        Poor|
# |0x171d| CUS_0x5b48|  August|null|  32.0|706-95-0150|      Lawyer|    12600.445|    782.0370833333334|                5|              5|           10|          3|Not Specified, St...|                 25|                    19|               15.79|                11.0|  Standard|           569.8|      31.978873515820702|12 Years and 10 M...|                  Yes| 26.060347529205966|      66.37358000122424|Low_spent_Small_v...|275.76978080290314|        Poor|
# |0x173b| CUS_0xb95f|February|null|  30.0|467-13-1148|      Writer|     34290.12|              2697.51|                9|              8|           25|          7|Home Equity Loan,...|                 47|                  null|               13.96|                 9.0|  Standard|         2686.81|      27.036842290717487|                  NA|                   NM|  185.1119825795006|                  10000|Low_spent_Large_v...| 196.5585016421765|    Standard|
# +------+-----------+--------+----+------+-----------+------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# only showing top 20 rows
#
# missing in Name None
# +------+-----------+--------+------------------+----+-----------+-------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |    ID|Customer_ID|   Month|              Name| Age|        SSN|   Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|        Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|  Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|   Payment_Behaviour|   Monthly_Balance|Credit_Score|
# +------+-----------+--------+------------------+----+-----------+-------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |0x160e| CUS_0x21b1| January|   Rick Rothackerj|null|004-07-5839|         null|     34847.84|    3037.986666666666|                2|              4|            6|          1| Credit-Builder Loan|                  3|                     4|                5.42|                 2.0|      Good|          605.03|       24.46403063758457|26 Years and 7 Mo...|                   No| 18.816214573128885|       104.291825168246|Low_spent_Small_v...|470.69062692529184|    Standard|
# |0x1650| CUS_0x284a|    July|            Nadiaq|null|       null|       Lawyer|   10909427.0|                 null|                0|              1|            8|          2|Credit-Builder Lo...|                  0|                     2|                9.34|                 4.0|      Good|          352.16|      26.947565152239882|31 Years and 1 Mo...|                   No|  911.2201793459374|      930.3918977796665|                null|326.24183015224526|        Good|
# |0x1658| CUS_0x5407|   March|              Annk|null|500-92-6408|Media_Manager|     34081.38|                 null|                8|              7|           15|          3|Not Specified, Au...|                 31|                    14|               17.13|                 5.0|  Standard|         1704.18|       35.11155247196594|14 Years and 9 Mo...|                  Yes|  70.47833267207261|      199.7207654954979|Low_spent_Large_v...| 260.9124018324295|        Poor|
# |0x1669| CUS_0x4157|  August|      Charlie Zhur|null|070-19-1622|       Doctor|    114838.41|            9843.8675|                2|              5|            7|          3|Personal Loan, De...|                 11|                    11|                8.24|                 8.0|      Good|         1377.74|      27.813353640375272|21 Years and 11 M...|                   No| 226.89279192154316|     254.57176724837916|High_spent_Large_...| 742.9221908300779|    Standard|
# |0x1687| CUS_0xc0ab|February|          Soyoungd|null|342-90-2649|     Engineer|     88640.24|    7266.686666666667|                3|              6|          433|          2|Payday Loan, and ...|                  4|                     2|                3.51|                 3.0|      Good|          950.36|      41.036168282350594|25 Years and 6 Mo...|                   NM| 135.17337097171767|       157.174788304235|High_spent_Large_...| 674.3205073907143|        Good|
# |0x1693| CUS_0x3e45|February|   Harriet McLeodd|null|414-53-2918| Entrepreneur|     54392.16|              4766.68|                6|              4|           14|          3|Not Specified, St...|                 10|                    10|                4.54|                 3.0|  Standard|          179.22|       29.40877527612245|26 Years and 11 M...|                  Yes| 124.39208242092043|     142.75186411942676|High_spent_Medium...|459.52405345965286|    Standard|
# |0x16b9| CUS_0x33d2|   April|         Chalmersa|null|965-46-2491|    Scientist|     31993.78|    2942.148333333333|                6|              6|            7|          2|Payday Loan, and ...|                  8|                    14|                6.28|                 1.0|      null|          818.22|       34.15826211876792|17 Years and 1 Mo...|                  Yes|  45.14129822463578|      152.4523258823164|Low_spent_Medium_...| 376.6212092263812|    Standard|
# |0x1716| CUS_0x5b48| January|              null|null|706-95-0150|       Lawyer|    12600.445|    782.0370833333334|                5|              5|           10|       -100|Not Specified, St...|                 28|                    19|               15.79|                 7.0|      null|           569.8|       33.07588356651339|12 Years and 3 Mo...|                  Yes| 26.060347529205966|                    0.0|High_spent_Large_...| 284.2982044805207|    Standard|
# |0x1755| CUS_0xbffe|   April|Dhanya Skariachano|null|311-13-7309|    Architect|     28572.39|                 null|                6|              3|           15|          3|Payday Loan, Not ...|                 25|                    14|                4.89|                 0.0|      null|          400.07|       34.71456103712383|30 Years and 6 Mo...|                  Yes|  69.60292048199007|      25.99346229581731|High_spent_Medium...| 375.4068672221926|    Standard|
# |0x1762| CUS_0xb681|     May|              null|null|904-88-7361|      Manager|     39641.54|                 null|               10|              8|           25|          6|Auto Loan, Studen...|                 61|                    16|                1.54|                 8.0|       Bad|         2258.73|       25.98322951266487|9 Years and 0 Months|                  Yes| 172.38252735862687|     254.26037253709117|                null| 154.1032667709486|    Standard|
# |0x176a| CUS_0x9a71| January|     Mukhopadhyayc|null|889-07-2357|    Scientist|     20186.02|    1684.168333333333|                1|              5|            1|          2|Auto Loan, and Ho...|                  5|                     6|                6.83|                 4.0|      null|          413.32|       35.94290748551229|18 Years and 3 Mo...|                   No| 29.534583720496048|      74.21434055467658|Low_spent_Large_v...| 334.6679090581607|        Good|
# |0x1782| CUS_0x95b5| January|   Lisa Baertleinu|null|602-55-1355|     Engineer|    12986.745|            959.22875|                4|              3|           10|          2|Mortgage Loan, an...|                 30|                    14|                11.8|                 5.0|      null|         1489.49|      26.329268870437282|8 Years and 8 Months|                  Yes| 16.719300227776053|     16.286719355483015|High_spent_Medium...|312.91685541674093|    Standard|
# |0x179f| CUS_0xb101|    June|   Andreas Cremerf|null|253-91-2822|    Scientist|     42171.98|    3764.331666666667|                2|              7|           10|          3|Auto Loan, Auto L...|                  2|                    10|                2.58|                 4.0|      null|          556.91|       29.46412057567319|21 Years and 10 M...|                   NM| 102.76291311709039|      82.51039863115369|High_spent_Small_...|451.15985491842264|        Good|
# |0x17d1| CUS_0x42ac|  August|         Lawrencea|null|700-60-3660|     Musician|     15566.02|    1423.168333333333|                8|              5|           32|          4|Home Equity Loan,...|                 17|                    23|                9.24|                 9.0|  Standard|         1693.95|      36.572989910187616|8 Years and 5 Months|                  Yes|  43.07051960231588|                   null|Low_spent_Medium_...| 333.9677311876703|    Standard|
# |0x17e8| CUS_0xb5ff|    July|              null|null|060-81-1328|Media_Manager|    12909.895|    853.8245833333333|                5|              5|           13|          0|                null|                 22|                    16|                7.58|                 3.0|  Standard|           602.5|      39.804292938731905|17 Years and 7 Mo...|                   No|                0.0|      51.48954251473581|Low_spent_Small_v...|323.89291581859754|    Standard|
# |0x1819| CUS_0xaedb|  August|      Olivia Oranr|null|       null|         null|     85554.03|            7185.5025|                4|              2|            3|          0|                null|                 12|                     7|                6.43|                 3.0|      Good|         1095.73|       41.51328788148247|                  NA|                   No|            81050.0|      78.79818322985322|High_spent_Large_...| 879.7520667701468|        Good|
# |0x183b| CUS_0x75c6|    June|  John ODonnell""p|null|587-65-8904|         null|     87215.68|    7489.973333333332|                2|              6|            8|          2|Auto Loan, and Pa...|                  6|                     4|                9.98|                 0.0|      Good|          680.77|       28.92882974582685|21 Years and 1 Mo...|                   No|            10292.0|     173.09436921741766|                null| 694.2209473793729|        Good|
# |0x1845| CUS_0x9b3c|   April|         Scheydere|null|224-48-7837|       Lawyer|     81842.28|              6810.19|               10|              9|           25|          9|Student Loan, Aut...|                 20|                    16|               14.25|                 9.0|       Bad|         3053.16|      27.926609653819963|                  NA|                  Yes|  574.0657978713467|     332.91312448523337|High_spent_Small_...| 34.04007764341981|    Standard|
# |0x1855| CUS_0x22a3|  August|     Nate Raymondj|null|477-90-5881|       Doctor|      95956.5|             8279.375|                8|              4|           11|          2|Personal Loan, an...|                 23|                  null|               11.94|                 2.0|  Standard|         1079.73|      41.341414000106546|32 Years and 2 Mo...|                   NM|   95.5216287821567|      552.1106827759281|Low_spent_Large_v...| 450.3051884419152|        Good|
# |0x1912| CUS_0x5cdf|     May|             Wohli|null|616-36-8188|     Musician|     75273.24|    6424.022011446845|                8|              6|           32|          5|Home Equity Loan,...|                 50|                     9|                12.8|                 8.0|  Standard|         2497.34|      35.274640154405134|5 Years and 6 Months|                   NM| 351.36704467467814|     141.18791019032327|High_spent_Medium...| 541.4700336881556|    Standard|
# +------+-----------+--------+------------------+----+-----------+-------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# only showing top 20 rows
#
# missing in Age None
# +------+-----------+-------+------------------+----+----+------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |    ID|Customer_ID|  Month|              Name| Age| SSN|  Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|        Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|  Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|   Payment_Behaviour|   Monthly_Balance|Credit_Score|
# +------+-----------+-------+------------------+----+----+------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |0x1609|  CUS_0xd40| August|              null|23.0|null|   Scientist|     19114.12|   1824.8433333333328|                3|              4|            3|          4|Auto Loan, Credit...|                  3|                     6|               11.27|                 4.0|      Good|          809.98|       23.93379480196552|                  NA|                   No|  49.57494921489417|     24.785216509052056|High_spent_Medium...|358.12416760938714|    Standard|
# |0x162b| CUS_0xb891|   June|            Jasond|55.0|null|        null|     30689.89|   2612.4908333333333|                2|              5|            4|          1|       Not Specified|                  5|                     6|               -3.01|                 4.0|      null|          632.46|        27.4454217928553|17 Years and 8 Mo...|                   No| 16.415451659824875|      84.95284817115969|High_spent_Small_...| 419.8807835023488|    Standard|
# |0x164d| CUS_0x284a|  April|            Nadiaq|34.0|null|      Lawyer|     131313.4|   10469.207759388815|                0|              1|            8|          2|Credit-Builder Lo...|                  0|                     2|                8.34|                 4.0|      Good|          352.16|       42.64578489930634|30 Years and 10 M...|                   No|            23834.0|     337.43495631738324|High_spent_Medium...| 899.1987716145285|        Good|
# |0x1650| CUS_0x284a|   July|            Nadiaq|null|null|      Lawyer|   10909427.0|                 null|                0|              1|            8|          2|Credit-Builder Lo...|                  0|                     2|                9.34|                 4.0|      Good|          352.16|      26.947565152239882|31 Years and 1 Mo...|                   No|  911.2201793459374|      930.3918977796665|                null|326.24183015224526|        Good|
# |0x1694| CUS_0x3e45|  March|   Harriet McLeodd|35.0|null|Entrepreneur|     54392.16|                 null|                6|              4|           14|          3|Not Specified, St...|                 15|                    11|                5.54|                 3.0|      null|          179.22|       31.25892846912917|27 Years and 0 Mo...|                   NM| 124.39208242092043|     33.349568589344514|High_spent_Large_...| 558.9263489897351|    Standard|
# |0x16bd| CUS_0x33d2| August|         Chalmersa|31.0|null|   Scientist|     31993.78|    2942.148333333333|                6|              6|            7|          2|Payday Loan, and ...|                  8|                    16|                6.28|                 1.0|  Standard|          818.22|      36.012793772472094|17 Years and 5 Mo...|                  Yes|  45.14129822463578|      97.58820324481087|Low_spent_Large_v...| 421.4853318638867|    Standard|
# |0x16c6| CUS_0x6070|    May|             Parkm|20.0|null|  Accountant|     92047.08|              7591.59|                6|              7|           16|          0|                null|                 16|                     8|                9.13|                 4.0|  Standard|         1296.64|        34.3576502428514|29 Years and 6 Mo...|                   NM|                0.0|      78.71934549426288|High_spent_Large_...| 920.4396545057373|        Poor|
# |0x16e9| CUS_0x4100|  April|             Reema|31.0|null|Entrepreneur|     19300.34|    1512.361666666667|                6|              7|           17|          5|Mortgage Loan, De...|                 51|                    19|                9.95|                 7.0|       Bad|         2430.21|      28.870386917234462|18 Years and 5 Mo...|                  Yes|  49.57206224445275|     61.428029874778424|High_spent_Small_...|300.23607454743546|    Standard|
# |0x16eb| CUS_0x4100|   June|             Reema|32.0|null|        null|     19300.34|    1512.361666666667|                6|           1029|           17|          5|Mortgage Loan, De...|                 51|                    17|                9.95|                 8.0|       Bad|         2430.21|       25.84779062032988|18 Years and 7 Mo...|                  Yes|  49.57206224445275|      83.44744882880191|Low_spent_Large_v...|288.21665559341204|        Poor|
# |0x16ed| CUS_0x4100| August|             Reema|32.0|null|Entrepreneur|     19300.34|    1512.361666666667|                6|              7|           17|          5|Mortgage Loan, De...|                 53|                    19|                9.95|                 8.0|       Bad|         2430.21|       23.70919322410504|18 Years and 9 Mo...|                  Yes|  49.57206224445275|      118.1855506983746|Low_spent_Medium_...| 263.4785537238393|    Standard|
# |0x16f2| CUS_0x132f|January|              null|41.0|null|    Musician|     19514.88|              1828.24|                7|              5|           17|          0|                null|                 30|                    12|                4.17|                 2.0|      null|           881.4|      26.084542750932684|19 Years and 3 Mo...|                   NM|                0.0|      50.14372713919671|High_spent_Medium...| 382.6802728608033|    Standard|
# |0x16f7| CUS_0x132f|   June|  Mark Felsenthald|41.0|null|        null|     19514.88|                 null|                7|              5|           17|          0|                null|                 30|                    12|                4.17|                 2.0|  Standard|           881.4|       38.78807246113495|19 Years and 8 Mo...|                   No|                0.0|      151.3776397937309|Low_spent_Small_v...| 321.4463602062691|        Poor|
# |0x170c| CUS_0xac86|  March|             Nickb|20.0|null|Entrepreneur|    106733.13|            8873.4275|                4|              4|         4975|          0|                null|                  2|                     6|                0.86|                 0.0|      Good|           76.23|      42.070458602150005|32 Years and 11 M...|                   No|                0.0|     172.03282853259896|High_spent_Large_...| 955.3099214674013|        Good|
# |0x1726| CUS_0xa5f9|    May|             Rickt|34.0|null|    Mechanic|     57983.12|    4720.926666666667|                9|              8|           31|          8|Payday Loan, Not ...|                 48|                    21|               10.27|                17.0|       Bad|         3532.83|       37.28428974024728|12 Years and 6 Mo...|                  Yes| 200.43261339470683|     205.25015227427863|Low_spent_Small_v...| 356.4099009976813|        Poor|
# |0x1729| CUS_0xa5f9| August|             Rickt|34.0|null|    Mechanic|     57983.12|    4720.926666666667|                9|              8|           31|          8|Payday Loan, Not ...|                 48|                    24|                7.27|                null|      null|         3532.83|      24.726351303352534|12 Years and 9 Mo...|                  Yes| 200.43261339470683|     159.13672195005464|High_spent_Medium...| 362.5233313219053|        Poor|
# |0x1735| CUS_0x4d43| August|            Reijik|48.0|null|Entrepreneur|     20787.69|            1999.3075|                8|           1381|           14|          3|Home Equity Loan,...|                 22|                    14|   8.129999999999999|                 3.0|      null|           614.6|      35.344187616472155|18 Years and 5 Mo...|                   No|  42.22199265643221|     21.745531229318935|High_spent_Large_...|375.96322611424887|    Standard|
# |0x1752| CUS_0xbffe|January|Dhanya Skariachano|40.0|null|   Architect|     28572.39|            2210.0325|                6|              3|           15|          3|Payday Loan, Not ...|                 25|                    12|                4.89|                 0.0|      null|          400.07|      24.422250680362033|30 Years and 3 Mo...|                  Yes|  69.60292048199007|      42.85050714738581|High_spent_Large_...|348.54982237062416|    Standard|
# |0x17ab| CUS_0x9b94|   June|               Bri|36.0|null|     Manager|      71681.4|              5799.45|                3|              6|           15|          1|       Not Specified|                  5|                     6|               10.44|                 0.0|  Standard|         1293.02|      34.983562067394985|26 Years and 0 Mo...|                  Yes|  53.92351397165268|       414.896549383656|Low_spent_Medium_...| 391.1249366446912|        Good|
# |0x17b4| CUS_0x4080|  March|         ra Alperx|16.0|null|    Mechanic|     29469.98|   2227.8316666666665|                7|              7|           24|       -100|Personal Loan, Cr...|                 53|                    24|               27.94|                11.0|      null|         3421.66|      31.212268791470517|13 Years and 4 Mo...|                  Yes|  69.68545857227979|      32.70665182089997|High_spent_Large_...|360.39105627348687|    Standard|
# |0x17cd| CUS_0x42ac|  April|         Lawrencea|37.0|null|    Musician|     15566.02|    1423.168333333333|                8|              5|           32|          4|Home Equity Loan,...|                 17|                    20|                9.24|                null|  Standard|         1693.95|      25.038052402331104|8 Years and 1 Months|                  Yes|            62073.0|      94.29931654720836|                null| 294.9469971838091|    Standard|
# +------+-----------+-------+------------------+----+----+------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# only showing top 20 rows
#
# missing in SSN None
# +------+-----------+--------+------------------+----+-----------+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |    ID|Customer_ID|   Month|              Name| Age|        SSN|Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|        Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|  Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|   Payment_Behaviour|   Monthly_Balance|Credit_Score|
# +------+-----------+--------+------------------+----+-----------+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+------------------+------------+
# |0x160e| CUS_0x21b1| January|   Rick Rothackerj|null|004-07-5839|      null|     34847.84|    3037.986666666666|                2|              4|            6|          1| Credit-Builder Loan|                  3|                     4|                5.42|                 2.0|      Good|          605.03|       24.46403063758457|26 Years and 7 Mo...|                   No| 18.816214573128885|       104.291825168246|Low_spent_Small_v...|470.69062692529184|    Standard|
# |0x161a| CUS_0x2dbc| January|            Langep|34.0|486-85-3974|      null|    143162.64|             12187.22|                1|              5|            8|          3|Auto Loan, Auto L...|                  5|                     8|                 7.1|                 3.0|      Good|         1303.01|      28.616734823006844|17 Years and 9 Mo...|                   No|  246.9923194537421|       168.413702679309|                null|1043.3159778669492|        Good|
# |0x161c| CUS_0x2dbc|   March|            Langep|34.0|486-85-3974|      null|    143162.64|                 null|                1|              5|            8|          3|Auto Loan, Auto L...|                  8|                     7|                11.1|                null|      Good|         1303.01|      26.519815391546498|17 Years and 11 M...|                   No|  246.9923194537421|                  10000|High_spent_Small_...|  715.741367403555|        Good|
# |0x161e| CUS_0x2dbc|     May|            Langep|34.0|486-85-3974|      null|    143162.64|             12187.22|                1|              5|            8|          3|Auto Loan, Auto L...|                 10|                     5|                 7.1|                 3.0|      Good|         1303.01|       31.37614957421204|18 Years and 1 Mo...|                   No|  246.9923194537421|      430.9475278803298|Low_spent_Large_v...| 810.7821526659284|        Good|
# |0x162b| CUS_0xb891|    June|            Jasond|55.0|       null|      null|     30689.89|   2612.4908333333333|                2|              5|            4|          1|       Not Specified|                  5|                     6|               -3.01|                 4.0|      null|          632.46|        27.4454217928553|17 Years and 8 Mo...|                   No| 16.415451659824875|      84.95284817115969|High_spent_Small_...| 419.8807835023488|    Standard|
# |0x163f| CUS_0x95ee|February|                Np|31.0|612-70-8987|      null|     73928.46|    5988.705000000001|                4|              5|            8|          0|                null|                  8|                     7|               10.14|                 2.0|      Good|           548.2|       42.76986440325711|32 Years and 0 Mo...|                   NM|                0.0|     172.93921446875606|Low_spent_Medium_...|  705.931285531244|        Good|
# |0x1659| CUS_0x5407|   April|              Annk|30.0|500-92-6408|      null|     34081.38|             2611.115|                8|              7|           15|          3|Not Specified, Au...|                 34|                    14|               21.13|                 5.0|      null|         1704.18|       29.76215930632113|14 Years and 10 M...|                  Yes|  70.47833267207261|     220.55219192916718|Low_spent_Small_v...| 260.0809753987602|        Poor|
# |0x165a| CUS_0x5407|     May|              Annk|30.0|500-92-6408|      null|     34081.38|             2611.115|                8|              7|           15|          3|Not Specified, Au...|                 27|                    14|               17.13|                 5.0|      null|         1704.18|      30.206214222610893|14 Years and 11 M...|                  Yes|  70.47833267207261|                   null|High_spent_Large_...| 397.2283547370202|    Standard|
# |0x167c| CUS_0xa66b|   March|           Saphirj|40.0|221-30-8554|      null|     33751.27|                 null|                5|              5|           20|          3|Credit-Builder Lo...|                 16|                    20|                11.0|                 8.0|  Standard|         1328.93|       38.03072168039317|19 Years and 4 Mo...|                  Yes|  65.00817428651536|     270.18258222151513|Low_spent_Large_v...| 229.6698268253028|    Standard|
# |0x16eb| CUS_0x4100|    June|             Reema|32.0|       null|      null|     19300.34|    1512.361666666667|                6|           1029|           17|          5|Mortgage Loan, De...|                 51|                    17|                9.95|                 8.0|       Bad|         2430.21|       25.84779062032988|18 Years and 7 Mo...|                  Yes|  49.57206224445275|      83.44744882880191|Low_spent_Large_v...|288.21665559341204|        Poor|
# |0x16f7| CUS_0x132f|    June|  Mark Felsenthald|41.0|       null|      null|     19514.88|                 null|                7|              5|           17|          0|                null|                 30|                    12|                4.17|                 2.0|  Standard|           881.4|       38.78807246113495|19 Years and 8 Mo...|                   No|                0.0|      151.3776397937309|Low_spent_Small_v...| 321.4463602062691|        Poor|
# |0x1703| CUS_0xa16e|    June|        Lee Chyenz|42.0|905-50-7912|      null|    10183.015|   1074.5845833333333|                7|              5|           17|          5|Credit-Builder Lo...|                 48|                    24|               10.97|              1050.0|       Bad|         1672.43|      25.105402554318484|10 Years and 6 Mo...|                  Yes|  37.58807283812568|      73.89986104079846|Low_spent_Small_v...| 285.9705244544092|        Poor|
# |0x1719| CUS_0x5b48|   April|              null|32.0|706-95-0150|      null|    12600.445|    782.0370833333334|                5|              5|           10|          3|Not Specified, St...|                 25|                    18|               15.79|                null|  Standard|           569.8|         28.819407058304|12 Years and 6 Mo...|                  Yes|            33746.0|      31.14919791081519|Low_spent_Medium_...| 300.9941628933122|        Poor|
# |0x172f| CUS_0x4d43|February|            Reijik|48.0|013-39-0742|      null|     20787.69|            1999.3075|                8|              6|           14|          3|Home Equity Loan,...|                 24|                  null|                1.13|                 3.0|  Standard|           614.6|      34.235852681958825|17 Years and 11 M...|                   No|  42.22199265643221|      82.62718037237505|Low_spent_Large_v...| 345.0815769711927|    Standard|
# |0x1730| CUS_0x4d43|   March|            Reijik|48.0|013-39-0742|      null|     20787.69|            1999.3075|                8|              6|           14|          3|Home Equity Loan,...|                 22|                  null|                1.13|                 3.0|  Standard|           614.6|       22.80214523254044|                  NA|                   No|  42.22199265643221|     110.17209563183977|Low_spent_Small_v...|337.53666171172796|    Standard|
# |0x173e| CUS_0xb95f|     May|           Ashleyk|30.0|467-13-1148|      null|     34290.12|              2697.51|                9|              8|           25|          7|Home Equity Loan,...|                 52|                    12|               13.96|                 9.0|      null|         2686.81|      33.841866041473175|14 Years and 0 Mo...|                  Yes|  185.1119825795006|       330.071842181316|Low_spent_Small_v...| 44.56717523918351|        Poor|
# ...
# |0x1753| CUS_0xbffe|February|Dhanya Skariachano|40.0|311-13-7309|    Architect|     28572.39|            2210.0325|                6|              3|           15|          3|Payday Loan, Not ...|                 25|                     9|                4.89|                 0.0|  Standard|          400.07|       36.43787041541562|30 Years and 4 Mo...|                   NM|  69.60292048199007|       83.0442090106474|             null| 358.3561205073625|    Standard|
# |0x1762| CUS_0xb681|     May|              null|null|904-88-7361|      Manager|     39641.54|                 null|               10|              8|           25|          6|Auto Loan, Studen...|                 61|                    16|                1.54|                 8.0|       Bad|         2258.73|       25.98322951266487|9 Years and 0 Months|                  Yes| 172.38252735862687|     254.26037253709117|             null| 154.1032667709486|    Standard|
# |0x178e| CUS_0x4004| January|           Carlosj|43.0|679-26-6464|       Writer|      58317.0|              4664.75|                8|              5|            9|          6|Mortgage Loan, Pe...|                 18|                    17|               16.58|                 6.0|  Standard|           98.97|        40.4111148274711|13 Years and 1 Mo...|                  Yes| 149.89719942100822|     109.48894961827229|             null| 467.0888509607195|    Standard|
# |0x179c| CUS_0xb101|   March|   Andreas Cremerf|37.0|253-91-2822|    Scientist|     42171.98|    3764.331666666667|                2|              7|           10|          3|Auto Loan, Auto L...|                  4|                  null|                2.58|                 4.0|      Good|          556.91|      40.150582768507526|21 Years and 7 Mo...|                   NM| 102.76291311709039|       97.5667563136885|             null| 446.1034972358877|    Standard|
# |0x179e| CUS_0xb101|     May|   Andreas Cremerf|37.0|253-91-2822|    Scientist|     42171.98|    3764.331666666667|                2|              7|           10|          3|Auto Loan, Auto L...|                  4|                    10|                2.58|                 4.0|      Good|          556.91|      31.745213385009905|21 Years and 9 Mo...|                   No| 102.76291311709039|      150.3131869839959|             null| 373.3570665655803|        Good|
# +------+-----------+--------+------------------+----+-----------+-------------+-------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+-----------------+------------------+------------+
# only showing top 20 rows
#
# missing in Payment_Behaviour None
# +------+-----------+--------+---------------+----+-----------+----------+------------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+---------------+------------+
# |    ID|Customer_ID|   Month|           Name| Age|        SSN|Occupation|     Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|        Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|  Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|   Payment_Behaviour|Monthly_Balance|Credit_Score|
# +------+-----------+--------+---------------+----+-----------+----------+------------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+---------------+------------+
# |0x1727| CUS_0xa5f9|    June|          Rickt|34.0|189-09-5267|  Mechanic|          57983.12|    4720.926666666667|                9|              8|           31|          8|Payday Loan, Not ...|                 46|                    21|                7.27|                17.0|       Bad|         3532.83|       35.25737829905026|12 Years and 7 Mo...|                  Yes| 200.43261339470683|       626.869242023209|Low_spent_Small_v...|           null|    Standard|
# |0x17d8| CUS_0x571f|   March| Emily Flitterl|18.0|397-28-9675| Developer|          66567.32|    5800.276666666668|                5|              7|            5|          2|Mortgage Loan, an...|                  7|                    12|                5.67|                 0.0|  Standard|          233.79|       33.48684838231401|24 Years and 5 Mo...|                   No| 100.18936089086122|      770.6964130785489|Low_spent_Small_v...|           null|    Standard|
# |0x1846| CUS_0x9b3c|     May|      Scheydere|43.0|224-48-7837|    Lawyer|          81842.28|                 null|               10|              9|           25|          9|Student Loan, Aut...|                 20|                    17|               16.25|                11.0|       Bad|         3053.16|       31.31743280165792|0 Years and 8 Months|                  Yes|  574.0657978713467|     447.84857819702745|Low_spent_Medium_...|           null|    Standard|
# |0x18ae| CUS_0x9d78| January|    Tim Hepherp|20.0|423-77-6457| Scientist|           69977.6|    5978.466666666667|               10|              7|           20|          9|Auto Loan, Person...|                 49|                    18|                6.81|                11.0|      null|         3042.36|        37.2171992978333|12 Years and 8 Mo...|                  Yes| 485.75043098703753|       405.149363619614|Low_spent_Small_v...|           null|    Standard|
# |0x18af| CUS_0x9d78|February|    Tim Hepherp|20.0|423-77-6457| Scientist|           69977.6|    5978.466666666667|               10|              7|           20|          9|Auto Loan, Person...|                 49|                    18|                6.81|                11.0|       Bad|         3042.36|      30.467836324821572|12 Years and 9 Mo...|                  Yes| 485.75043098703753|       470.837204280824|Low_spent_Large_v...|           null|        Poor|
# |0x18b4| CUS_0x9d78|    July|    Tim Hepherp|21.0|423-77-6457| Scientist|           69977.6|    5978.466666666667|               10|              7|           20|          9|Auto Loan, Person...|                 49|                    19|                6.81|                11.0|       Bad|         3042.36|      30.351272009679175|13 Years and 2 Mo...|                  Yes| 485.75043098703753|      545.6759426739467|Low_spent_Medium_...|           null|    Standard|
# |0x18b5| CUS_0x9d78|  August|    Tim Hepherp|21.0|423-77-6457| Scientist|           69977.6|    5978.466666666667|               10|              7|           20|          9|Auto Loan, Person...|                 49|                    18|                6.81|                11.0|       Bad|         3042.36|       36.25111094816326|                  NA|                   NM| 485.75043098703753|     510.01476319312724|Low_spent_Large_v...|           null|    Standard|
# |0x19bc| CUS_0x700d|    July|    Blenkinsopc|21.0|992-49-2793|      null|          44719.17|            3969.5975|                6|              6|           29|          7|Payday Loan, Auto...|                 42|                    19|               28.21|                11.0|      null|         3818.57|       37.25127281543517|13 Years and 5 Mo...|                  Yes| 248.59988585543798|     446.41009136448434|Low_spent_Small_v...|           null|        Poor|
# |0x1a0e| CUS_0xa335|     May|Lisa Baertleink|21.0|835-41-6871| Architect|           66105.4|    5653.783333333333|                6|              8|           31|          5|Mortgage Loan, Au...|                 23|                    22|                5.52|                 9.0|       Bad|         1549.56|      31.756711872440725|11 Years and 6 Mo...|                  Yes| 214.07212305606225|      732.6818427000247|Low_spent_Small_v...|           null|        Poor|
# |0x1a79| CUS_0x12d5|   April|      ita Bosed|null|518-01-2262| Scientist|          62320.56|              5068.38|                9|              9|           18|          5|Debt Consolidatio...|                 23|                    15|               17.24|                15.0|       Bad|         3589.56|       34.73441661919471|1 Years and 7 Months|                  Yes| 171.34555972446432|      672.9965674057812|Low_spent_Small_v...|           null|    Standard|
# |0x1a90| CUS_0x62c6|   March|            B.u|20.0|860-36-1556|    Writer|         144881.68|   11877.473333333333|                3|              4|           15|          4|Student Loan, Deb...|                  5|                    13|                10.1|                 2.0|      null|          404.51|       36.28893235896684|                  NA|                  Yes| 414.65601320398537|     1270.3279611808646|Low_spent_Small_v...|           null|    Standard|
# |0x1a94| CUS_0x62c6|    July|            B.u|20.0|860-36-1556|    Writer|         144881.68|   11877.473333333333|                3|              4|           15|          4|Student Loan, Deb...|                  1|                    13|                 8.1|                 2.0|  Standard|          404.51|       34.78184822250499|26 Years and 3 Mo...|                  Yes| 414.65601320398537|     1075.4156812000438|                null|           null|    Standard|
# |0x1acb| CUS_0xb6ad|February|         Jamiec|24.0|584-60-4961|    Lawyer|           61008.0|               5235.0|               10|              5|           32|          4|Auto Loan, Auto L...|                 16|                    19|               19.44|                12.0|  Standard|         1755.81|       32.45474798862161|8 Years and 10 Mo...|                  Yes|  189.4265306646308|      677.4251029457807|Low_spent_Small_v...|           null|        Poor|
# |0x1b8b| CUS_0x1288|February|        Taylorq|33.0|609-85-2725|    Doctor|          60938.13|            5163.1775|               10|              8|           31|          8|Payday Loan, Payd...|                 23|                    18|               16.49|                 9.0|      null|         3947.24|       24.10018316599713|                  NA|                  Yes|   378.304673376643|                  10000|Low_spent_Small_v...|           null|        Poor|
# |0x1b8c| CUS_0x1288|   March|        Taylorq|33.0|609-85-2725|    Doctor|          60938.13|            5163.1775|               10|              8|           31|          8|Payday Loan, Payd...|                 26|                    17|               17.49|                76.0|       Bad|         3947.24|      25.821122097648335|5 Years and 0 Months|                  Yes|   378.304673376643|      570.8378293960601|Low_spent_Small_v...|           null|    Standard|
# |0x1b8e| CUS_0x1288|     May|        Taylorq|34.0|609-85-2725|    Doctor|          60938.13|            5163.1775|               10|           1130|           31|          8|Payday Loan, Payd...|                 26|                    21|               17.49|                 9.0|       Bad|         3947.24|       35.40968589093354|5 Years and 2 Months|                  Yes|   378.304673376643|      464.5784431851196|                null|           null|        Poor|
# |0x1b90| CUS_0x1288|    July|           null|34.0|609-85-2725|    Doctor|          60938.13|            5163.1775|               10|              8|           31|       -100|Payday Loan, Payd...|                 26|                    18|               17.49|                 9.0|      null|         3947.24|      28.909928454902047|5 Years and 4 Months|                  Yes|   378.304673376643|     509.04521941935053|Low_spent_Small_v...|           null|        Poor|
# |0x1dd8| CUS_0x4028|   March|  Papachristouy|36.0|407-45-5883|   Manager|          68935.26|             5518.605|                1|              5|            8|          3|Credit-Builder Lo...|                 14|                     9|                3.25|                 4.0|      Good|          457.81|      37.452093977798384|25 Years and 6 Mo...|                   No| 102.79630864901532|      739.7896615721454|                null|           null|        Good|
# |0x1f3e| CUS_0x8a4b| January|           null|51.0|142-99-2481|    Doctor|110786.63999999998|                 null|                4|              6|            5|          3|Auto Loan, Person...|                 12|                    15|                8.68|                 1.0|  Standard|           226.7|      31.054184723304548|24 Years and 4 Mo...|                  Yes|   209.314506964946|     1203.1056676333058|Low_spent_Small_v...|           null|    Standard|
# |0x1f7e| CUS_0x543f|     May|Lucia Mutikanid|23.0|333-87-6291|  Mechanic|          51824.94|             4417.745|                6|              7|           26|          8|Debt Consolidatio...|                 39|                    24|                0.63|                 8.0|       Bad|         2958.02|      29.497447281029192|7 Years and 7 Months|                  Yes|  257.6594544707495|      508.8561454168993|Low_spent_Small_v...|           null|        Poor|
# +------+-----------+--------+---------------+----+-----------+----------+------------------+---------------------+-----------------+---------------+-------------+-----------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+---------------+------------+
# only showing top 20 rows
#
# missing in Monthly_Balance None
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# | ID|Customer_ID|Month|Name|Age|SSN|Occupation|Annual_Income|Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|Payment_Behaviour|Monthly_Balance|Credit_Score|
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
# +---+-----------+-----+----+---+---+----------+-------------+---------------------+-----------------+---------------+-------------+-----------+------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+------------------+---------------------+-------------------+-----------------------+-----------------+---------------+------------+
#
# missing in Credit_Score None

# %% [markdown]
# ##### <u>2.1.3. Describe the columns with missing values

# %% [markdown]
# Now, it seems that we have missing values for Name
# Monthly_Inhand_Salary,
# Type_of_Loan,
# Num_of_Delayed_Payment,
# Num_Credit_Inquiries,
# Amount_invested_monthly,
# Monthly_Balance.So we will use describe to explore the data in the columns

# %%
# inspecting the numerical columns with missing values
df.select(['Monthly_Inhand_Salary','Num_of_Delayed_Payment','Num_Credit_Inquiries','Amount_invested_monthly','Monthly_Balance']).describe().show()
# Out:
# +-------+---------------------+----------------------+--------------------+-----------------------+--------------------+
# |summary|Monthly_Inhand_Salary|Num_of_Delayed_Payment|Num_Credit_Inquiries|Amount_invested_monthly|     Monthly_Balance|
# +-------+---------------------+----------------------+--------------------+-----------------------+--------------------+
# |  count|                84998|                 92998|               98035|                  95521|               98800|
# |   mean|    4194.170849600451|    30.923342437471774|   27.75425103279441|      637.4129984078696|-3.03643724696356...|
# | stddev|     3183.68616687327|    226.03189164449924|   193.1773389800335|     2043.3193274670227|3.181295008384093E24|
# |    min|    303.6454166666666|                    -1|                 0.0|                    0.0|-3333333333333333...|
# |    max|   15204.633333333333|                   996|              2597.0|      999.8610676363429|   999.8134716639598|
# +-------+---------------------+----------------------+--------------------+-----------------------+--------------------+

# %% [markdown]
# Since name and Type_of_Loan are categorical values, we have only described the numerical columns

# %% [markdown]
# Now we will also describe() all our columns

# %%
df.describe().show()
# Out:
# +-------+-------+-----------+------+------------------+------------------+-----------+----------+------------------+---------------------+------------------+-----------------+------------------+-----------------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+-----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+--------------------+------------+
# |summary|     ID|Customer_ID| Month|              Name|               Age|        SSN|Occupation|     Annual_Income|Monthly_Inhand_Salary| Num_Bank_Accounts|  Num_Credit_Card|     Interest_Rate|      Num_of_Loan|        Type_of_Loan|Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix| Outstanding_Debt|Credit_Utilization_Ratio|  Credit_History_Age|Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|   Payment_Behaviour|     Monthly_Balance|Credit_Score|
# +-------+-------+-----------+------+------------------+------------------+-----------+----------+------------------+---------------------+------------------+-----------------+------------------+-----------------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+-----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+--------------------+------------+
# |  count| 100000|     100000|100000|             90015|             95061|      94428|     92938|            100000|                84998|            100000|           100000|            100000|           100000|               88592|             100000|                 92998|               97909|               98035|     79805|           100000|                  100000|              100000|               100000|             100000|                  95521|               92400|               98800|      100000|
# |   mean|   null|       null|  null|              null|110.93450521244253|       null|      null|176415.70129815137|    4194.170849600451|          17.09128|         22.47443|          72.46604|          3.00996|                null|           21.06878|    30.923342437471774|  10.389025115158105|   27.75425103279441|      null|1426.220375999983|      32.285172518943504|                null|                 null| 1403.1182166159901|      637.4129984078696|                null|-3.03643724696356...|        null|
# | stddev|   null|       null|  null|              null| 689.4078643530464|       null|      null|1429618.0514141538|     3183.68616687327|117.40483442734816|129.0574101100985|466.42262122171513|62.64787936048814|                null| 14.860104223678107|    226.03189164449924|   6.789496202377736|   193.1773389800335|      null|1155.129025746459|       5.116875070150913|                null|                 null|  8306.041270321715|     2043.3193274670227|                null|3.181295008384093E24|        null|
# |    min|0x10002| CUS_0x1000| April|A. Ananthalakshmih|            -500.0|000-08-1349|Accountant|        10001727.0|    303.6454166666666|                -1|                0|                 1|             -100|           Auto Loan|                 -5|                    -1|-0.00999999999999...|                 0.0|       Bad|             0.23|                    20.0|0 Years and 1 Months|                   NM|                0.0|                    0.0|High_spent_Large_...|-3333333333333333...|        Good|
# |    max| 0xfffd|  CUS_0xffd|   May|                yv|            8698.0|999-99-3421|    Writer|          99995.22|   15204.633333333333|              1798|             1499|              5797|              999|Student Loan, and...|                 67|                   996|                9.99|              2597.0|  Standard|           999.48|       50.00000000000001|                  NA|                  Yes|            82331.0|      999.8610676363429|Low_spent_Small_v...|   999.8134716639598|    Standard|
# +-------+-------+-----------+------+------------------+------------------+-----------+----------+------------------+---------------------+------------------+-----------------+------------------+-----------------+--------------------+-------------------+----------------------+--------------------+--------------------+----------+-----------------+------------------------+--------------------+---------------------+-------------------+-----------------------+--------------------+--------------------+------------+

# %% [markdown]
# ##### <u>2.1.4. Check the datatypes of missing values

# %%
# we will be checking the data types of the missing value cols
df[['Name','Monthly_Inhand_Salary','Num_of_Delayed_Payment','Num_Credit_Inquiries','Amount_invested_monthly','Monthly_Balance']].dtypes
# Out:
# [('Name', 'string'),
#  ('Monthly_Inhand_Salary', 'double'),
#  ('Num_of_Delayed_Payment', 'string'),
#  ('Num_Credit_Inquiries', 'double'),
#  ('Amount_invested_monthly', 'string'),
#  ('Monthly_Balance', 'string')]

# %% [markdown]
# ##### <u>2.1.5. Filling missing vallues</u>
# Now we need to impute the missing values. We can do that by dropping the rows that have missing values, filling in the missing values with a test
# statistic (such as mean, mode, or median), or predicting the missing values using a machine learning algorithm.<br>

# %% [markdown]
# #####<u>2.1.6. Filling the numerical columns</u>

# %%
df=df.fillna('ffill', subset=['Monthly_Inhand_Salary','Num_of_Delayed_Payment','Num_Credit_Inquiries','Amount_invested_monthly','Monthly_Balance'])

# %%
def dirty_data_finding(df):
    dirty = []
    columns = df.columns
    for col in columns:
        dtype = df[col].dtypes
        nunique = df[col].nunique()
        null = df[col].isnull().sum()
        duplicates = df[col].duplicated().sum()
        dirty.append([col,dtype,nunique,null,duplicates])
    df_dirty_data_finding = pd.DataFrame(dirty)
    df_dirty_data_finding.columns = ['column','dtype','nunique','null','duplicates']
    return df_dirty_data_finding

dirty_data_finding(df.toPandas())
# Out:
#                       column    dtype  nunique   null  duplicates
# 0                         ID   object   100000      0           0
# 1                Customer_ID   object    12500      0       87500
# 2                      Month   object        8      0       99992
# 3                       Name   object    10128   9985       89871
# 4                        Age  float64     1661   4939       98338
# 5                        SSN   object    12500   5572       87499
# 6                 Occupation   object       15   7062       99984
# 7              Annual_Income   object    13487      0       86513
# 8      Monthly_Inhand_Salary  float64    13235  15002       86764
# 9          Num_Bank_Accounts    int64      943      0       99057
# 10           Num_Credit_Card    int64     1179      0       98821
# 11             Interest_Rate    int64     1750      0       98250
# 12               Num_of_Loan   object      414      0       99586
# 13              Type_of_Loan   object     6260  11408       93739
# 14       Delay_from_due_date    int64       73      0       99927
# 15    Num_of_Delayed_Payment   object      711   7002       99288
# 16      Changed_Credit_Limit   object     4383   2091       95616
# 17      Num_Credit_Inquiries  float64     1223   1965       98776
# 18                Credit_Mix   object        3  20195       99996
# 19          Outstanding_Debt   object    12203      0       87797
# 20  Credit_Utilization_Ratio  float64   100000      0           0
# 21        Credit_History_Age   object      405      0       99595
# 22     Payment_of_Min_Amount   object        3      0       99997
# 23       Total_EMI_per_month  float64    14950      0       85050
# 24   Amount_invested_monthly   object    91049   4479        8950
# 25         Payment_Behaviour   object        6   7600       99993
# 26           Monthly_Balance   object    98792   1200        1207
# 27              Credit_Score   object        3      0       99997

# %%
import re
import urllib.request
import sys
import os
import argparse
import json
import requests

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'£\d+\.?\d*|\d+\.?\d*bn|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars|\d+\.?\d*bn dollar|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars|\d+\.?\d*bn dollar|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars|\d+\.?\d*bn dollar|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars|\d+\.?\d*bn dollar|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars|\d+\.?\d*bn dollar|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars|\d+\.?\d*bn dollar|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars|\d+\.?\d*bn dollar|\d+\.?\d*bn euros|\d+\.?\d*bn euro|\d+\.?\d*bn pounds|\d+\.?\d*bn pound|\d+\.?\d*bn dollars')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()
# Out:
# 0bn
# 1bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 0bn
# 1bn
# 1bn
# 131bn
# £100
# 100bn
# 17.4bn
# 0bn
# 0bn
# 1bn
# 1bn
# 1bn
# 1bn
# 1bn
# 1bn
# 1bn
# 1bn
# 1bn
# 0bn
# 1bn
# 1bn
# 1bn
# 0bn
# £600
# 131bn
# £100
# 131bn
# £100
# 100bn
# 17.4bn
# 100bn
# 17.4bn
# £600
# £600
# £600

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'£\d+\.?\d*[m]?')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()
# Out:
# £100
# £600
# £100
# £100
# £600
# £600
# £600

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'\$\d+\.?\d*[m]?')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()
# Out:
# $131
# $100
# $17.4
# $131
# $131
# $100
# $17.4
# $100
# $17.4

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'\d+\.?\d*[m]?\s[euro]')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()
# Out:
# 0 r
# 2009 r
# 2009 r
# 2009 r

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'\d+\.?\d*[m]?\s[euros]')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()
# Out:
# 0 r
# 1 s
# 61 s
# 4800 s
# 2009 r
# 2009 r
# 2009 r

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'\d+\.?\d*[m]?\s[bn]')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'\d+\.?\d*[m]?\s[p]')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()
# Out:
# 2 p
# 2 p
# 2 p
# 2 p

# %%
def main():

    url = "https://www.bbc.co.uk/news/business-41779341"
    response = requests.get(url)
    if response.status_code != 200:
        print('Error: Could not get URL')
        sys.exit(1)

    text = response.text
    # regex = re.compile(r'\£\d+\.?\d*')
    regex=re.compile(r'\d+\.?\d*[m]?\s[euro]|\d+\.?\d*[m]?\s[euros]|\d+\.?\d*[m]?\s[bn]|\d+\.?\d*[m]?\s[p]')
    matches = regex.findall(text)
    for match in matches:
        print(match)

if __name__ == '__main__':
    main()
# Out:
# 0 r
# 1 s
# 61 s
# 4800 s
# 2009 r
# 2 p
# 2009 r
# 2009 r
# 2 p
# 2 p
# 2 p

# %%
import re
x = input("Enter the text: ")
# regex for all phonenumbers
y = re.findall(r'\d{3}\.\d{3}\.\d{4}|\+\d{1}\-\(\d{3}\)\-\d{3}\-\d{4}|\d{1}\-\(\d{3}\)\-\d{3}\-\d{4}|\d{1}\-\d{3}\-\d{3}\-\d{4}|\d{3}\-\d{3}\-\d{4}|\d{3}\s\d{3}\s\d{4}|\(\d{3}\)\s\d{3}\s\d{4}|\(\d{3}\)\-\d{3}\-\d{4}|\d{10}|\d{3}\.\d{3}\.\d{4}|\d{3}\.\d{4}|\d{3}\-\d{4}|\d{10}|\d{11}', x)
print("-----"*20)
print(y)
# Out:
# Enter the text: +1-(800)-545-2468 2-(800)-545-2468 3-800-545-2468 555-123-3456 555 222 3342 (234) 234 2442 (243)-234-2342 1234567890 123.456.7890 123.4567 123-4567 1234567900 12345678900
# ----------------------------------------------------------------------------------------------------
# ['+1-(800)-545-2468', '2-(800)-545-2468', '3-800-545-2468', '555-123-3456', '555 222 3342', '(234) 234 2442', '(243)-234-2342', '1234567890', '123.456.7890', '123.4567', '123-4567', '1234567900', '1234567890']

# %%
# +1-(800)-545-2468
# 2-(800)-545-2468
# 3-800-545-2468
# 555-123-3456
# 555 222 3342
# (234) 234 2442
# (243)-234-2342
# 1234567890
# 123.456.7890
# 123.4567
# 123-4567
# 1234567900
# 12345678900
